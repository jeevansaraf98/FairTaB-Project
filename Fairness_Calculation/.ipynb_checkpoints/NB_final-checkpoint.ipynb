# %%
import warnings

import numpy as np
import pandas as pd

from sklearn import preprocessing
from sklearn.model_selection import StratifiedKFold as KFold
from sklearn.naive_bayes import GaussianNB

from my_useful_functions import (
    calculate_performance_statistical_parity,
    calculate_performance_equalized_odds,
    calculate_performance_equal_opportunity,
    calculate_performance_predictive_parity,
    calculate_performance_predictive_equality,
    calculate_performance_treatment_equality,
)
from compute_abroca import compute_abroca

warnings.filterwarnings("ignore")

from pathlib import Path

OUTPUT_DIR = Path("results")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
def _postprocess_split(
    df: pd.DataFrame,
    protected_attribute: str,
    class_label: str,
    filename: str,
    majority_group_name: str,
    minority_group_name: str,
):

    if class_label not in df.columns:
        raise ValueError(
            f"class_label '{class_label}' not found in dataframe columns: {df.columns.tolist()}"
        )

    cols = [c for c in df.columns if c != class_label] + [class_label]
    df = df[cols]

    p_Group = 0

    for col in df.select_dtypes(include=["object", "category"]).columns:
        le = preprocessing.LabelEncoder()
        le.fit(df[col])

        if col == protected_attribute:
            if majority_group_name in le.classes_:
                p_Group = int(np.where(le.classes_ == majority_group_name)[0][0])

        df[col] = le.transform(df[col])

    X = df.iloc[:, :-1].copy()
    y = df.iloc[:, -1].copy()

    y = y.replace(0, -1)

    feature_names = X.columns.tolist()
    if protected_attribute not in feature_names:
        raise ValueError(
            f"protected_attribute '{protected_attribute}' not found in features: {feature_names}"
        )
    sa_index = feature_names.index(protected_attribute)

    return (
        X,
        y,
        sa_index,
        p_Group,
        protected_attribute,
        filename,
        majority_group_name,
        minority_group_name,
    )

# %%
def recode_original(df: pd.DataFrame, dataset_name: str) -> pd.DataFrame:

    # -------- Compas-Original --------
    if dataset_name == "Compas-Original":
        if not {"juv_fel_count", "juv_misd_count", "juv_other_count"}.issubset(df.columns):
            raise ValueError("Compas-Original is missing juvenile count columns.")

        df["juv_crime"] = (
            df["juv_fel_count"] + df["juv_misd_count"] + df["juv_other_count"]
        )

        selected_cols = [
            "race",
            "sex",
            "two_year_recid",
            "score_text",
            "priors_count",
            "age_cat",
            "v_score_text",
            "juv_crime",
            "c_charge_degree",
        ]
        missing = [c for c in selected_cols if c not in df.columns]
        if missing:
            raise ValueError(f"Compas-Original is missing columns: {missing}")
        df = df[selected_cols]

    # -------- Compas-Violent-Original --------
    elif dataset_name == "Compas-Violent-Original":
        if not {"juv_fel_count", "juv_misd_count", "juv_other_count"}.issubset(df.columns):
            raise ValueError("Compas-Violent-Original is missing juvenile count columns.")

        df["juv_crime"] = (
            df["juv_fel_count"] + df["juv_misd_count"] + df["juv_other_count"]
        )

        selected_cols = [
            "race",
            "sex",
            "two_year_recid",
            "score_text",
            "priors_count",
            "age_cat",
            "v_score_text",
            "juv_crime",
            "c_charge_degree",
        ]
        missing = [c for c in selected_cols if c not in df.columns]
        if missing:
            raise ValueError(f"Compas-Violent-Original is missing columns: {missing}")
        df = df[selected_cols]

    return df


def add_binary_race(df, dataset_name: str, new_col="race_bin"):
    if "race" not in df.columns:
        raise ValueError(f"{dataset_name}: expected column 'race' not found")

    if dataset_name.endswith("Original"):
        df[new_col] = np.where(df["race"] == "Caucasian", "Caucasian", "Non-Caucasian")
    else:
        df[new_col] = np.where(df["race"] == 2, "Caucasian", "Non-Caucasian")

    return df

# %%
def load_dataset(dataset_name: str):

    CONFIG = {
        # --------- LAW ----------
        "Law-Original": {
            "path": "data/law_school_clean.csv",
            "protected_attribute": "male",
            "class_label": "pass_bar",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Law-Original.abroca.pdf",
        },
        "Law-Synthetic": {
            "path": "data/law_synthetic.csv",
            "protected_attribute": "male",
            "class_label": "pass_bar",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Law-Synthetic.abroca.pdf",
        },
        "Law-Debiased": {
            "path": "data/law_debiased.csv",
            "protected_attribute": "male",
            "class_label": "pass_bar",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Law-Debiased.abroca.pdf",
        },
        "Law-FLAI": {
            "path": "data/Law-Flai-new-synthetic_fair_data.csv",
            "protected_attribute": "male",
            "class_label": "pass_bar",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Law-FLAI.abroca.pdf",
        },
        "Law-DECAF": {
            "path": "data/law_decaf.csv",
            "protected_attribute": "male",
            "class_label": "pass_bar",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Law-DECAF.abroca.pdf",
        },

        # --------- ADULT ----------
        "Adult-Original": {
            "path": "data/adult-clean.csv",
            "protected_attribute": "gender",
            "class_label": "Class-label",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Adult-Original.abroca.pdf",
        },
        "Adult-Synthetic": {
            "path": "data/adult_synthetic.csv",
            "protected_attribute": "gender",
            "class_label": "Class-label",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Adult-Synthetic.abroca.pdf",
        },
        "Adult-Debiased": {
            "path": "data/adult_debiased.csv",
            "protected_attribute": "gender",
            "class_label": "Class-label",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Adult-Debiased.abroca.pdf",
        },
        "Adult-FLAI": {
            "path": "data/Adult-Flai-new-synthetic_fair_data.csv",
            "protected_attribute": "gender",
            "class_label": "Class-label",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Adult-FLAI.abroca.pdf",
        },
        "Adult-DECAF": {
            "path": "data/adult_decaf.csv",
            "protected_attribute": "gender",
            "class_label": "Class-label",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Adult-DECAF.abroca.pdf",
        },

        # --------- COMPAS (non-violent) ----------
        "Compas-Original": {
            "path": "data/compas-scores-two-years_clean.csv",
            "protected_attribute": "sex",
            "class_label": "two_year_recid",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            # "protected_attribute": "race_bin",
            # "majority_group_name": "Caucasian",
            # "minority_group_name": "Non-Caucasian",
            "filename": "Ada.Compas-Original.abroca.pdf",
        },
        "Compas-Synthetic": {
            "path": "data/compas_synthetic.csv",
            "protected_attribute": "sex",
            "class_label": "two_year_recid",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            # "protected_attribute": "race_bin",
            # "majority_group_name": "Caucasian",
            # "minority_group_name": "Non-Caucasian",
            "filename": "Ada.Compas-Synthetic.abroca.pdf",
        },
        "Compas-Debiased": {
            "path": "data/compas_debiased.csv",
            "protected_attribute": "sex",
            "class_label": "two_year_recid",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            # "protected_attribute": "race_bin",
            # "majority_group_name": "Caucasian",
            # "minority_group_name": "Non-Caucasian",
            "filename": "Ada.Compas-Debiased.abroca.pdf",
        },
        "Compas-FLAI": {
            "path": "data/Compas-Flai-new-synthetic_fair_data.csv",
            "protected_attribute": "sex",
            "class_label": "two_year_recid",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            # "protected_attribute": "race_bin",
            # "majority_group_name": "Caucasian",
            # "minority_group_name": "Non-Caucasian",
            "filename": "Ada.Compas-FLAI.abroca.pdf",
        },
        "Compas-DECAF": {
            "path": "data/compas_decaf.csv",
            "protected_attribute": "sex",
            "class_label": "two_year_recid",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            # "protected_attribute": "race_bin",
            # "majority_group_name": "Caucasian",
            # "minority_group_name": "Non-Caucasian",
            "filename": "Ada.Compas-DECAF.abroca.pdf",
        },

        # --------- COMPAS-VIOLENT ----------
        "Compas-Violent-Original": {
            "path": "data/compas-scores-two-years-violent_clean.csv",
            "protected_attribute": "sex",
            "class_label": "two_year_recid",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            # "protected_attribute": "race_bin",
            # "majority_group_name": "Caucasian",
            # "minority_group_name": "Non-Caucasian",
            "filename": "Ada.Compas-Violent-Original.abroca.pdf",
        },
        "Compas-Violent-Synthetic": {
            "path": "data/compas_violent_synthetic.csv",
            "protected_attribute": "sex",
            "class_label": "two_year_recid",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            # "protected_attribute": "race_bin",
            # "majority_group_name": "Caucasian",
            # "minority_group_name": "Non-Caucasian",
            "filename": "Ada.Compas-Violent-Synthetic.abroca.pdf",
        },
        "Compas-Violent-Debiased": {
            "path": "data/compas_violent_debiased.csv",
            "protected_attribute": "sex",
            "class_label": "two_year_recid",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            # "protected_attribute": "race_bin",
            # "majority_group_name": "Caucasian",
            # "minority_group_name": "Non-Caucasian",
            "filename": "Ada.Compas-Violent-Debiased.abroca.pdf",
        },
        "Compas-Violent-FLAI": {
            "path": "data/Compas-Violent-Flai-new-synthetic_fair_data.csv",
            "protected_attribute": "sex",
            "class_label": "two_year_recid",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            # "protected_attribute": "race_bin",
            # "majority_group_name": "Caucasian",
            # "minority_group_name": "Non-Caucasian",
            "filename": "Ada.Compas-Violent-FLAI.abroca.pdf",
        },
        "Compas-Violent-DECAF": {
            "path": "data/compas_violent_decaf.csv",
            "protected_attribute": "sex",
            "class_label": "two_year_recid",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            # "protected_attribute": "race_bin",
            # "majority_group_name": "Caucasian",
            # "minority_group_name": "Non-Caucasian",
            "filename": "Ada.Compas-Violent-DECAF.abroca.pdf",
        },

        # --------- DIABETES ----------
        "Diabetes-Original": {
            "path": "data/diabetes-clean.csv",
            "protected_attribute": "gender",
            "class_label": "readmitted",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Diabetes-Original.abroca.pdf",
        },
        "Diabetes-Synthetic": {
            "path": "data/diabetes_synthetic.csv",
            "protected_attribute": "gender",
            "class_label": "readmitted",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Diabetes-Synthetic.abroca.pdf",
        },
        "Diabetes-Debiased": {
            "path": "data/diabetes_debiased.csv",
            "protected_attribute": "gender",
            "class_label": "readmitted",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Diabetes-Debiased.abroca.pdf",
        },
        "Diabetes-FLAI": {
            "path": "data/diabetes_flai.csv",
            "protected_attribute": "gender",
            "class_label": "readmitted",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Diabetes-FLAI.abroca.pdf",
        },
        "Diabetes-DECAF": {
            "path": "data/diabetes_decaf.csv",
            "protected_attribute": "gender",
            "class_label": "readmitted",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Diabetes-DECAF.abroca.pdf",
        },

        # --------- DUTCH ----------
        "Dutch-Original": {
            "path": "data/dutch.csv",
            "protected_attribute": "sex",
            "class_label": "occupation",
            "majority_group_name": "male",
            "minority_group_name": "female",
            "filename": "Ada.Dutch-Original.abroca.pdf",
        },
        "Dutch-Synthetic": {
            "path": "data/dutch_synthetic.csv",
            "protected_attribute": "sex",
            "class_label": "occupation",
            "majority_group_name": "male",
            "minority_group_name": "female",
            "filename": "Ada.Dutch-Synthetic.abroca.pdf",
        },
        "Dutch-Debiased": {
            "path": "data/dutch_debiased.csv",
            "protected_attribute": "sex",
            "class_label": "occupation",
            "majority_group_name": "male",
            "minority_group_name": "female",
            "filename": "Ada.Dutch-Debiased.abroca.pdf",
        },
        "Dutch-FLAI": {
            "path": "data/Dutch-Flai-new-synthetic_fair_data.csv",
            "protected_attribute": "sex",
            "class_label": "occupation",
            "majority_group_name": "male",
            "minority_group_name": "female",
            "filename": "Ada.Dutch-FLAI.abroca.pdf",
        },
        "Dutch-DECAF": {
            "path": "data/dutch_decaf.csv",
            "protected_attribute": "sex",
            "class_label": "occupation",
            "majority_group_name": "male",
            "minority_group_name": "female",
            "filename": "Ada.Dutch-DECAF.abroca.pdf",
        },
    }

    if dataset_name not in CONFIG:
        raise ValueError(f"Unknown dataset_name '{dataset_name}'")

    cfg = CONFIG[dataset_name]

    df = pd.read_csv(cfg["path"])

    if dataset_name.endswith("Original"):
        df = recode_original(df, dataset_name)

    # if dataset_name.startswith("Compas"):
    #     df = add_binary_race(df, dataset_name, new_col="race_bin")

    return _postprocess_split(
        df=df,
        protected_attribute=cfg["protected_attribute"],
        class_label=cfg["class_label"],
        filename=cfg["filename"],
        majority_group_name=cfg["majority_group_name"],
        minority_group_name=cfg["minority_group_name"],
    )

# %%
def run_experiment_nb(
    X,
    y,
    sa_index,
    p_Group,
    protected_attribute,
    filename,
    majority_group_name,
    minority_group_name,
    dataset_name: str,
):

    kf = KFold(n_splits=10, shuffle=True, random_state=42)
    results = []

    for fold, (train_index, test_index) in enumerate(kf.split(X, y)):

        X_train_fold = X.iloc[train_index].copy()
        X_test_fold  = X.iloc[test_index].copy()
        y_train_fold = y.iloc[train_index].copy()
        y_test_fold  = y.iloc[test_index].copy()

        # ----- Model: Gaussian Naive Bayes -----
        nb = GaussianNB()
        nb.fit(X_train_fold, y_train_fold)

        y_predicts = nb.predict(X_test_fold)

        if hasattr(nb, "predict_proba"):
            proba = nb.predict_proba(X_test_fold)
            class_idx = np.where(nb.classes_ == 1)[0]
            if len(class_idx) == 1:
                pos_idx = class_idx[0]
            else:
                pos_idx = -1
            y_pred_probs = proba[:, pos_idx]
        else:
            y_pred_probs = np.zeros_like(y_predicts, dtype=float)

        y_test_bin = (y_test_fold == 1).astype(int).values
        y_pred_bin = (y_predicts == 1).astype(int)

        # ----- Fairness & performance metrics -----

        # Statistical parity also returns accuracy & balanced accuracy
        sp_stats = calculate_performance_statistical_parity(
            X_test_fold.values, y_test_bin, y_pred_bin, sa_index, p_Group
        )
        acc  = sp_stats.get("accuracy", 0.0)
        bacc = sp_stats.get("balanced_accuracy", 0.0)
        sp   = sp_stats.get("fairness", 0.0)

        eo = calculate_performance_equal_opportunity(
            X_test_fold.values, y_test_bin, y_pred_bin, sa_index, p_Group
        ).get("fairness", 0.0)

        eod = calculate_performance_equalized_odds(
            X_test_fold.values, y_test_bin, y_pred_bin, y_pred_probs, sa_index, p_Group
        ).get("fairness", 0.0)

        pp = calculate_performance_predictive_parity(
            X_test_fold.values, y_test_bin, y_pred_bin, sa_index, p_Group
        ).get("fairness", 0.0)

        pe = calculate_performance_predictive_equality(
            X_test_fold.values, y_test_bin, y_pred_bin, sa_index, p_Group
        ).get("fairness", 0.0)

        te = calculate_performance_treatment_equality(
            X_test_fold.values, y_test_bin, y_pred_bin, sa_index, p_Group
        ).get("fairness", 0.0)

        # ----- ABROCA -----
        if dataset_name == "Dutch-DECAF":
            abroca = np.nan
        else:
            X_test_tmp = X_test_fold.copy()
            X_test_tmp["pred_proba"] = y_pred_probs
            X_test_tmp["true_label"] = y_test_fold.values

            abroca = compute_abroca(
                X_test_tmp,
                pred_col="pred_proba",
                label_col="true_label",
                protected_attr_col=protected_attribute,
                majority_protected_attr_val=p_Group,
                n_grid=10000,
                plot_slices=False,
                majority_group_name=majority_group_name,
                minority_group_name=minority_group_name,
                file_name=f"{dataset_name}_Fold{fold + 1}_" + filename,
            )

        results.append(
            {
                "Accuracy":            acc,
                "Balanced Accuracy":   bacc,
                "Statistical Parity":  sp,
                "Equal Opportunity":   eo,
                "Equalized Odds":      eod,
                "Predictive Parity":   pp,
                "Predictive Equality": pe,
                "Treatment Equality":  te,
                "ABROCA":              abroca,
            }
        )

    df_results = pd.DataFrame(results)
    avg_results = df_results.mean().round(4)

    print(f"\n===== Average Results Across Folds (Naive Bayes Model) | {dataset_name} =====")
    print(avg_results.to_frame(name="Average NB (10-Fold)").T)

    avg_results_df = avg_results.reset_index()
    avg_results_df.columns = ["Fairness Metric", "NB"]

    # Optional per-dataset CSV
    # out_name = f"{dataset_name}_nb_results_new1.csv"
    # avg_results_df.to_csv(OUTPUT_DIR / out_name, index=False)
    # print(f"Saved per-dataset NB results: {out_name}")

    return avg_results_df

# %%
def run_all_datasets_nb():
    dataset_names = [
        "Law-Original", "Law-Synthetic", "Law-Debiased", "Law-FLAI", "Law-DECAF",
        "Adult-Original", "Adult-Synthetic", "Adult-Debiased", "Adult-FLAI", "Adult-DECAF",
        "Compas-Original", "Compas-Synthetic", "Compas-Debiased", "Compas-FLAI", "Compas-DECAF",
        "Compas-Violent-Original", "Compas-Violent-Synthetic", "Compas-Violent-Debiased",
        "Compas-Violent-FLAI", "Compas-Violent-DECAF",
        "Diabetes-Original", "Diabetes-Synthetic", "Diabetes-Debiased",
        # "Diabetes-FLAI", 
        "Diabetes-DECAF",
        "Dutch-Original", "Dutch-Synthetic", "Dutch-Debiased",
        "Dutch-FLAI", "Dutch-DECAF",
        # "Compas-FLAI", "Compas-Violent-FLAI"
    ]

    all_results = []

    for name in dataset_names:
        print("\n===========================================")
        print(f"Running Naive Bayes on dataset: {name}")

        (
            X,
            y,
            sa_index,
            p_Group,
            protected_attribute,
            filename,
            majority_group_name,
            minority_group_name,
        ) = load_dataset(name)

        avg_df = run_experiment_nb(
            X,
            y,
            sa_index,
            p_Group,
            protected_attribute,
            filename,
            majority_group_name,
            minority_group_name,
            dataset_name=name,
        )

        avg_df.insert(0, "Dataset", name)
        all_results.append(avg_df)

    combined = pd.concat(all_results, ignore_index=True)

    # Final combined CSV / Excel
    # combined.to_csv(OUTPUT_DIR / "Combined_NB_results.csv", index=False)
    # Or:
    # combined.to_excel("Combined_NB_results.xlsx", index=False)

    print("\nSaved Combined_NB_results.csv with all datasets.")
    return combined

combined_nb_results = run_all_datasets_nb()
# Out:
# ===========================================
# Running Naive Bayes on dataset: Law-Original
#
# ===== Average Results Across Folds (Naive Bayes Model) | Law-Original =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)    0.8133             0.7711              0.0315
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)             0.0196          0.0589             0.0077
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)               0.0394              0.0106  0.0247
#
# ===========================================
# Running Naive Bayes on dataset: Law-Synthetic
#
# ===== Average Results Across Folds (Naive Bayes Model) | Law-Synthetic =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)    0.6764             0.6753             -0.0108
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)             0.0254          0.0751             0.0423
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)               0.0497              0.0188  0.0349
#
# ===========================================
# Running Naive Bayes on dataset: Law-Debiased
#
# ===== Average Results Across Folds (Naive Bayes Model) | Law-Debiased =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)    0.6469                0.5                 0.0
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)                0.0             0.0             0.0172
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)                  0.0                 0.0  0.0503
#
# ===========================================
# Running Naive Bayes on dataset: Law-FLAI
#
# ===== Average Results Across Folds (Naive Bayes Model) | Law-FLAI =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)    0.7646              0.739              0.0239
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)             0.0269          0.0709             0.0125
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)                0.044             -0.5064  0.0393
#
# ===========================================
# Running Naive Bayes on dataset: Law-DECAF
#
# ===== Average Results Across Folds (Naive Bayes Model) | Law-DECAF =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)    0.8339             0.9111              0.9944
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)                1.0          1.9922             0.2854
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)               0.9922                 inf     NaN
#
# ===========================================
# Running Naive Bayes on dataset: Adult-Original
#
# ===== Average Results Across Folds (Naive Bayes Model) | Adult-Original =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)    0.7884             0.6277             -0.0643
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)             0.0278          0.0456             0.2129
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)               0.0179               3.162  0.0511
#
# ===========================================
# Running Naive Bayes on dataset: Adult-Synthetic
#
# ===== Average Results Across Folds (Naive Bayes Model) | Adult-Synthetic =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)    0.7475              0.748              0.0228
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)             0.0266          0.0541             0.0352
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)               0.0275              0.1705  0.0241
#
# ===========================================
# Running Naive Bayes on dataset: Adult-Debiased
#
# ===== Average Results Across Folds (Naive Bayes Model) | Adult-Debiased =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)    0.6257             0.5266              0.0137
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)             0.0276          0.0775             0.0297
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)               0.0498              0.0171    0.05
#
# ===========================================
# Running Naive Bayes on dataset: Adult-FLAI
#
# ===== Average Results Across Folds (Naive Bayes Model) | Adult-FLAI =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)    0.7857             0.7075              0.2426
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)             0.3375          0.4784             0.1568
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)               0.1409              1.8792  0.0701
#
# ===========================================
# Running Naive Bayes on dataset: Adult-DECAF
#
# ===== Average Results Across Folds (Naive Bayes Model) | Adult-DECAF =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)    0.9886             0.9886                 1.0
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)                1.0             2.0             0.9849
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)                  1.0                 inf  0.0399
#
# ===========================================
# Running Naive Bayes on dataset: Compas-Original
#
# ===== Average Results Across Folds (Naive Bayes Model) | Compas-Original =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)    0.6633             0.6443             -0.2322
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)             0.3131          0.4444             0.1297
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)               0.1313             -9.0013   0.066
#
# ===========================================
# Running Naive Bayes on dataset: Compas-Synthetic
#
# ===== Average Results Across Folds (Naive Bayes Model) | Compas-Synthetic =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)    0.7483                0.5                 0.0
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)                0.0             0.0             0.0289
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)                  0.0                 0.0  0.0598
#
# ===========================================
# Running Naive Bayes on dataset: Compas-Debiased
#
# ===== Average Results Across Folds (Naive Bayes Model) | Compas-Debiased =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)    0.5085             0.4933             -0.1225
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)             0.1376           0.244             0.0307
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)               0.1063             -0.1784  0.0365
#
# ===========================================
# Running Naive Bayes on dataset: Compas-FLAI
#
# ===== Average Results Across Folds (Naive Bayes Model) | Compas-FLAI =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)    0.6571             0.6401              0.1218
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)             0.1476          0.2171             0.0737
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)               0.0696              0.8204   0.049
#
# ===========================================
# Running Naive Bayes on dataset: Compas-DECAF
#
# ===== Average Results Across Folds (Naive Bayes Model) | Compas-DECAF =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)    0.9459             0.9557              0.9234
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)             0.3115           1.048             0.0952
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)               0.7365              1.7661  0.0116
#
# ===========================================
# Running Naive Bayes on dataset: Compas-Violent-Original
#
# ===== Average Results Across Folds (Naive Bayes Model) | Compas-Violent-Original =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)    0.8279             0.6177             -0.1053
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)              0.215          0.2853             0.2478
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)               0.0702                -inf  0.1233
#
# ===========================================
# Running Naive Bayes on dataset: Compas-Violent-Synthetic
#
# ===== Average Results Across Folds (Naive Bayes Model) | Compas-Violent-Synthetic =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)     0.659                0.5                 0.0
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)                0.0             0.0                0.0
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)                  0.0                 NaN  0.0469
#
# ===========================================
# Running Naive Bayes on dataset: Compas-Violent-Debiased
#
# ===== Average Results Across Folds (Naive Bayes Model) | Compas-Violent-Debiased =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)    0.8136                0.5                 0.0
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)                0.0             0.0                0.0
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)                  0.0                 NaN   0.049
#
# ===========================================
# Running Naive Bayes on dataset: Compas-Violent-FLAI
#
# ===== Average Results Across Folds (Naive Bayes Model) | Compas-Violent-FLAI =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)    0.8168             0.6067              0.0405
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)             0.1006          0.1326             0.1071
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)               0.0319              0.1441  0.0711
#
# ===========================================
# Running Naive Bayes on dataset: Compas-Violent-DECAF
#
# ===== Average Results Across Folds (Naive Bayes Model) | Compas-Violent-DECAF =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)    0.7922              0.669             -0.3251
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)             0.5248          0.5506             0.7927
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)               0.0258                -inf  0.2492
#
# ===========================================
# Running Naive Bayes on dataset: Diabetes-Original
#
# ===== Average Results Across Folds (Naive Bayes Model) | Diabetes-Original =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)    0.7579                0.5                 0.0
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)                0.0             0.0             0.0112
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)                  0.0                 0.0  0.0204
#
# ===========================================
# Running Naive Bayes on dataset: Diabetes-Synthetic
#
# ===== Average Results Across Folds (Naive Bayes Model) | Diabetes-Synthetic =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)    0.6602             0.6386             -0.0301
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)             0.0567          0.0997             0.0249
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)               0.0429             -0.0596  0.0395
#
# ===========================================
# Running Naive Bayes on dataset: Diabetes-Debiased
#
# ===== Average Results Across Folds (Naive Bayes Model) | Diabetes-Debiased =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)    0.5879             0.5716              0.0034
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)             0.0326          0.0801             0.0337
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)               0.0475             -0.0099  0.0338
#
# ===========================================
# Running Naive Bayes on dataset: Diabetes-DECAF
#
# ===== Average Results Across Folds (Naive Bayes Model) | Diabetes-DECAF =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)    0.7373                0.5                 0.0
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)                0.0             0.0             0.0209
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)                  0.0                 0.0  0.0595
#
# ===========================================
# Running Naive Bayes on dataset: Dutch-Original
#
# ===== Average Results Across Folds (Naive Bayes Model) | Dutch-Original =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)     0.806             0.8029              -0.259
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)             0.0451          0.1674             0.0606
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)               0.1222              0.3529  0.0283
#
# ===========================================
# Running Naive Bayes on dataset: Dutch-Synthetic
#
# ===== Average Results Across Folds (Naive Bayes Model) | Dutch-Synthetic =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)     0.693             0.6288             -0.0128
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)             0.0197          0.0711             0.0243
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)               0.0514             -0.0214  0.0391
#
# ===========================================
# Running Naive Bayes on dataset: Dutch-Debiased
#
# ===== Average Results Across Folds (Naive Bayes Model) | Dutch-Debiased =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)    0.5306             0.5159              -0.208
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)             0.2195           0.416             0.0401
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)               0.1964             -5.3096  0.0324
#
# ===========================================
# Running Naive Bayes on dataset: Dutch-FLAI
#
# ===== Average Results Across Folds (Naive Bayes Model) | Dutch-FLAI =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)    0.7532             0.7498              0.1604
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)             0.0755          0.2398             0.0295
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)               0.1642             -0.4195  0.1024
#
# ===========================================
# Running Naive Bayes on dataset: Dutch-DECAF
#
# ===== Average Results Across Folds (Naive Bayes Model) | Dutch-DECAF =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average NB (10-Fold)    0.5166              0.497              0.1865
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average NB (10-Fold)             0.1833           0.994             0.1838
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average NB (10-Fold)               0.1893                 inf     NaN
#
# Saved Combined_NB_results.csv with all datasets.

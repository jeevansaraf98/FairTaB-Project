# %%
import warnings

import numpy as np
import pandas as pd

from sklearn import preprocessing
from sklearn.model_selection import StratifiedKFold as KFold
from sklearn.tree import DecisionTreeClassifier 

from my_useful_functions import (
    calculate_performance_statistical_parity,
    calculate_performance_equalized_odds,
    calculate_performance_equal_opportunity,
    calculate_performance_predictive_parity,
    calculate_performance_predictive_equality,
    calculate_performance_treatment_equality,
)
from compute_abroca import compute_abroca

warnings.filterwarnings("ignore")

from pathlib import Path

OUTPUT_DIR = Path("results")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
def _postprocess_split(
    df: pd.DataFrame,
    protected_attribute: str,
    class_label: str,
    filename: str,
    majority_group_name: str,
    minority_group_name: str,
):
    if class_label not in df.columns:
        raise ValueError(
            f"class_label '{class_label}' not found in dataframe columns: {df.columns.tolist()}"
        )

    cols = [c for c in df.columns if c != class_label] + [class_label]
    df = df[cols]

    p_Group = 0

    for col in df.select_dtypes(include=["object", "category"]).columns:
        le = preprocessing.LabelEncoder()
        le.fit(df[col])

        if col == protected_attribute:
            if majority_group_name in le.classes_:
                p_Group = int(np.where(le.classes_ == majority_group_name)[0][0])

        df[col] = le.transform(df[col])

    X = df.iloc[:, :-1].copy()
    y = df.iloc[:, -1].copy()

    y = y.replace(0, -1)

    feature_names = X.columns.tolist()
    if protected_attribute not in feature_names:
        raise ValueError(
            f"protected_attribute '{protected_attribute}' not found in features: {feature_names}"
        )
    sa_index = feature_names.index(protected_attribute)

    return (
        X,
        y,
        sa_index,
        p_Group,
        protected_attribute,
        filename,
        majority_group_name,
        minority_group_name,
    )

# %%
def recode_original(df: pd.DataFrame, dataset_name: str) -> pd.DataFrame:

    # -------- Compas-Original --------
    if dataset_name == "Compas-Original":
        if not {"juv_fel_count", "juv_misd_count", "juv_other_count"}.issubset(df.columns):
            raise ValueError("Compas-Original is missing juvenile count columns.")

        df["juv_crime"] = (
            df["juv_fel_count"] + df["juv_misd_count"] + df["juv_other_count"]
        )

        selected_cols = [
            "race",
            "sex",
            "two_year_recid",
            "score_text",
            "priors_count",
            "age_cat",
            "v_score_text",
            "juv_crime",
            "c_charge_degree",
        ]
        missing = [c for c in selected_cols if c not in df.columns]
        if missing:
            raise ValueError(f"Compas-Original is missing columns: {missing}")
        df = df[selected_cols]

    # -------- Compas-Violent-Original --------
    elif dataset_name == "Compas-Violent-Original":
        if not {"juv_fel_count", "juv_misd_count", "juv_other_count"}.issubset(df.columns):
            raise ValueError("Compas-Violent-Original is missing juvenile count columns.")

        df["juv_crime"] = (
            df["juv_fel_count"] + df["juv_misd_count"] + df["juv_other_count"]
        )

        selected_cols = [
            "race",
            "sex",
            "two_year_recid",
            "score_text",
            "priors_count",
            "age_cat",
            "v_score_text",
            "juv_crime",
            "c_charge_degree",
        ]
        missing = [c for c in selected_cols if c not in df.columns]
        if missing:
            raise ValueError(f"Compas-Violent-Original is missing columns: {missing}")
        df = df[selected_cols]

    return df


def add_binary_race(df, dataset_name: str, new_col="race_bin"):
    if "race" not in df.columns:
        raise ValueError(f"{dataset_name}: expected column 'race' not found")

    if dataset_name.endswith("Original"):
        df[new_col] = np.where(df["race"] == "Caucasian", "Caucasian", "Non-Caucasian")
    else:
        df[new_col] = np.where(df["race"] == 2, "Caucasian", "Non-Caucasian")

    return df

# %%
def load_dataset(dataset_name: str):

    CONFIG = {
        # --------- LAW ----------
        "Law-Original": {
            "path": "data/law_school_clean.csv",
            "protected_attribute": "male",
            "class_label": "pass_bar",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Law-Original.abroca.pdf",
        },
        "Law-Synthetic": {
            "path": "data/law_synthetic.csv",   
            "protected_attribute": "male",
            "class_label": "pass_bar",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Law-Synthetic.abroca.pdf",
        },
        "Law-Debiased": {
            "path": "data/law_debiased.csv",    
            "protected_attribute": "male",
            "class_label": "pass_bar",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Law-Debiased.abroca.pdf",
        },
        "Law-FLAI": {
            "path": "data/Law-Flai-new-synthetic_fair_data.csv",
            "protected_attribute": "male",
            "class_label": "pass_bar",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Law-FLAI.abroca.pdf",
        },
        "Law-DECAF": {
            "path": "data/law_decaf.csv",
            "protected_attribute": "male",
            "class_label": "pass_bar",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Law-DECAF.abroca.pdf",
        },

        # --------- ADULT ----------
        "Adult-Original": {
            "path": "data/adult-clean.csv",
            "protected_attribute": "gender",
            "class_label": "Class-label",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Adult-Original.abroca.pdf",
        },
        "Adult-Synthetic": {
            "path": "data/adult_synthetic.csv",
            "protected_attribute": "gender",
            "class_label": "Class-label",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Adult-Synthetic.abroca.pdf",
        },
        "Adult-Debiased": {
            "path": "data/adult_debiased.csv",
            "protected_attribute": "gender",
            "class_label": "Class-label",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Adult-Debiased.abroca.pdf",
        },
        "Adult-FLAI": {
            "path": "data/Adult-Flai-new-synthetic_fair_data.csv",
            "protected_attribute": "gender",
            "class_label": "Class-label",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Adult-FLAI.abroca.pdf",
        },
        "Adult-DECAF": {
            "path": "data/adult_decaf.csv",
            "protected_attribute": "gender",
            "class_label": "Class-label",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Adult-DECAF.abroca.pdf",
        },

        # --------- COMPAS (non-violent) ----------
        "Compas-Original": {
            "path": "data/compas-scores-two-years_clean.csv",
            "protected_attribute": "sex",
            "class_label": "two_year_recid",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            # "protected_attribute": "race_bin",
            # "majority_group_name": "Caucasian",
            # "minority_group_name": "Non-Caucasian",
            "filename": "Ada.Compas-Original.abroca.pdf",
        },
        "Compas-Synthetic": {
            "path": "data/compas_synthetic.csv",
            "protected_attribute": "sex",
            "class_label": "two_year_recid",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            # "protected_attribute": "race_bin",
            # "majority_group_name": "Caucasian",
            # "minority_group_name": "Non-Caucasian",
            "filename": "Ada.Compas-Synthetic.abroca.pdf",
        },
        "Compas-Debiased": {
            "path": "data/compas_debiased.csv",
            "protected_attribute": "sex",
            "class_label": "two_year_recid",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            # "protected_attribute": "race_bin",
            # "majority_group_name": "Caucasian",
            # "minority_group_name": "Non-Caucasian",
            "filename": "Ada.Compas-Debiased.abroca.pdf",
        },
        "Compas-FLAI": {
            "path": "data/Compas-Flai-new-synthetic_fair_data.csv",
            "protected_attribute": "sex",
            "class_label": "two_year_recid",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            # "protected_attribute": "race_bin",
            # "majority_group_name": "Caucasian",
            # "minority_group_name": "Non-Caucasian",
            "filename": "Ada.Compas-FLAI.abroca.pdf",
        },
        "Compas-DECAF": {
            "path": "data/compas_decaf.csv",
            "protected_attribute": "sex",
            "class_label": "two_year_recid",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            # "protected_attribute": "race_bin",
            # "majority_group_name": "Caucasian",
            # "minority_group_name": "Non-Caucasian",
            "filename": "Ada.Compas-DECAF.abroca.pdf",
        },

        # --------- COMPAS-VIOLENT ----------
        "Compas-Violent-Original": {
            "path": "data/compas-scores-two-years-violent_clean.csv",
            "protected_attribute": "sex",
            "class_label": "two_year_recid",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            # "protected_attribute": "race_bin",
            # "majority_group_name": "Caucasian",
            # "minority_group_name": "Non-Caucasian",
            "filename": "Ada.Compas-Violent-Original.abroca.pdf",
        },
        "Compas-Violent-Synthetic": {
            "path": "data/compas_violent_synthetic.csv",
            "protected_attribute": "sex",
            "class_label": "two_year_recid",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            # "protected_attribute": "race_bin",
            # "majority_group_name": "Caucasian",
            # "minority_group_name": "Non-Caucasian",
            "filename": "Ada.Compas-Violent-Synthetic.abroca.pdf",
        },
        "Compas-Violent-Debiased": {
            "path": "data/compas_violent_debiased.csv",
            "protected_attribute": "sex",
            "class_label": "two_year_recid",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            # "protected_attribute": "race_bin",
            # "majority_group_name": "Caucasian",
            # "minority_group_name": "Non-Caucasian",
            "filename": "Ada.Compas-Violent-Debiased.abroca.pdf",
        },
        "Compas-Violent-FLAI": {
            "path": "data/Compas-Violent-Flai-new-synthetic_fair_data.csv",
            "protected_attribute": "sex",
            "class_label": "two_year_recid",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            # "protected_attribute": "race_bin",
            # "majority_group_name": "Caucasian",
            # "minority_group_name": "Non-Caucasian",
            "filename": "Ada.Compas-Violent-FLAI.abroca.pdf",
        },
        "Compas-Violent-DECAF": {
            "path": "data/compas_violent_decaf.csv",
            "protected_attribute": "sex",
            "class_label": "two_year_recid",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            # "protected_attribute": "race_bin",
            # "majority_group_name": "Caucasian",
            # "minority_group_name": "Non-Caucasian",
            "filename": "Ada.Compas-Violent-DECAF.abroca.pdf",
        },

        # --------- DIABETES ----------
        "Diabetes-Original": {
            "path": "data/diabetes-clean.csv",
            "protected_attribute": "gender",
            "class_label": "readmitted",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Diabetes-Original.abroca.pdf",
        },
        "Diabetes-Synthetic": {
            "path": "data/diabetes_synthetic.csv",
            "protected_attribute": "gender",
            "class_label": "readmitted",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Diabetes-Synthetic.abroca.pdf",
        },
        "Diabetes-Debiased": {
            "path": "data/diabetes_debiased.csv",
            "protected_attribute": "gender",
            "class_label": "readmitted",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Diabetes-Debiased.abroca.pdf",
        },
        "Diabetes-FLAI": {
            "path": "data/diabetes_flai.csv",
            "protected_attribute": "gender",
            "class_label": "readmitted",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Diabetes-FLAI.abroca.pdf",
        },
        "Diabetes-DECAF": {
            "path": "data/diabetes_decaf.csv",
            "protected_attribute": "gender",
            "class_label": "readmitted",
            "majority_group_name": "Male",
            "minority_group_name": "Female",
            "filename": "Ada.Diabetes-DECAF.abroca.pdf",
        },

        # --------- DUTCH ----------
        "Dutch-Original": {
            "path": "data/dutch.csv",
            "protected_attribute": "sex",
            "class_label": "occupation",
            "majority_group_name": "male",
            "minority_group_name": "female",
            "filename": "Ada.Dutch-Original.abroca.pdf",
        },
        "Dutch-Synthetic": {
            "path": "data/dutch_synthetic.csv",
            "protected_attribute": "sex",
            "class_label": "occupation",
            "majority_group_name": "male",
            "minority_group_name": "female",
            "filename": "Ada.Dutch-Synthetic.abroca.pdf",
        },
        "Dutch-Debiased": {
            "path": "data/dutch_debiased.csv",
            "protected_attribute": "sex",
            "class_label": "occupation",
            "majority_group_name": "male",
            "minority_group_name": "female",
            "filename": "Ada.Dutch-Debiased.abroca.pdf",
        },
        "Dutch-FLAI": {
            "path": "data/Dutch-Flai-new-synthetic_fair_data.csv",
            "protected_attribute": "sex",
            "class_label": "occupation",
            "majority_group_name": "male",
            "minority_group_name": "female",
            "filename": "Ada.Dutch-FLAI.abroca.pdf",
        },
        "Dutch-DECAF": {
            "path": "data/dutch_decaf.csv",
            "protected_attribute": "sex",
            "class_label": "occupation",
            "majority_group_name": "male",
            "minority_group_name": "female",
            "filename": "Ada.Dutch-DECAF.abroca.pdf",
        },
    }

    if dataset_name not in CONFIG:
        raise ValueError(f"Unknown dataset_name '{dataset_name}'")

    cfg = CONFIG[dataset_name]

    df = pd.read_csv(cfg["path"])

    if dataset_name.endswith("Original"):
        df = recode_original(df, dataset_name)

    # if dataset_name.startswith("Compas"):
    #     df = add_binary_race(df, dataset_name, new_col="race_bin")

    return _postprocess_split(
        df=df,
        protected_attribute=cfg["protected_attribute"],
        class_label=cfg["class_label"],
        filename=cfg["filename"],
        majority_group_name=cfg["majority_group_name"],
        minority_group_name=cfg["minority_group_name"],
    )

# %%
def run_experiment_dt(
    X,
    y,
    sa_index,
    p_Group,
    protected_attribute,
    filename,
    majority_group_name,
    minority_group_name,
    dataset_name: str,
):

    kf = KFold(n_splits=10, shuffle=True, random_state=42)
    results = []

    for fold, (train_index, test_index) in enumerate(kf.split(X, y)):

        X_train_fold = X.iloc[train_index].copy()
        X_test_fold  = X.iloc[test_index].copy()
        y_train_fold = y.iloc[train_index].copy()
        y_test_fold  = y.iloc[test_index].copy()

        # ----- Model: Decision Tree -----
        dt = DecisionTreeClassifier(
            random_state=1,
            # You can tune if you like:
            # max_depth=None,
            # min_samples_split=2,
            # min_samples_leaf=1,
        )
        dt.fit(X_train_fold, y_train_fold)

        y_predicts = dt.predict(X_test_fold)

        if hasattr(dt, "predict_proba"):
            y_pred_probs = dt.predict_proba(X_test_fold)[:, 1]
        else:
            y_pred_probs = np.zeros_like(y_predicts, dtype=float)

        y_test_bin = (y_test_fold == 1).astype(int).values
        y_pred_bin = (y_predicts == 1).astype(int)

        # ----- Fairness & performance metrics -----

        sp_stats = calculate_performance_statistical_parity(
            X_test_fold.values, y_test_bin, y_pred_bin, sa_index, p_Group
        )
        acc  = sp_stats.get("accuracy", 0.0)
        bacc = sp_stats.get("balanced_accuracy", 0.0)
        sp   = sp_stats.get("fairness", 0.0)

        eo = calculate_performance_equal_opportunity(
            X_test_fold.values, y_test_bin, y_pred_bin, sa_index, p_Group
        ).get("fairness", 0.0)

        eod = calculate_performance_equalized_odds(
            X_test_fold.values, y_test_bin, y_pred_bin, y_pred_probs, sa_index, p_Group
        ).get("fairness", 0.0)

        pp = calculate_performance_predictive_parity(
            X_test_fold.values, y_test_bin, y_pred_bin, sa_index, p_Group
        ).get("fairness", 0.0)

        pe = calculate_performance_predictive_equality(
            X_test_fold.values, y_test_bin, y_pred_bin, sa_index, p_Group
        ).get("fairness", 0.0)

        te = calculate_performance_treatment_equality(
            X_test_fold.values, y_test_bin, y_pred_bin, sa_index, p_Group
        ).get("fairness", 0.0)

        # ----- ABROCA -----
        if dataset_name == "Dutch-DECAF":
            abroca = np.nan
        else:
            X_test_tmp = X_test_fold.copy()
            X_test_tmp["pred_proba"] = y_pred_probs
            X_test_tmp["true_label"] = y_test_fold.values

            abroca = compute_abroca(
                X_test_tmp,
                pred_col="pred_proba",
                label_col="true_label",
                protected_attr_col=protected_attribute,
                majority_protected_attr_val=p_Group,
                n_grid=10000,
                plot_slices=False,
                majority_group_name=majority_group_name,
                minority_group_name=minority_group_name,
                file_name=f"{dataset_name}_Fold{fold + 1}_" + filename,
            )

        results.append(
            {
                "Accuracy":            acc,
                "Balanced Accuracy":   bacc,
                "Statistical Parity":  sp,
                "Equal Opportunity":   eo,
                "Equalized Odds":      eod,
                "Predictive Parity":   pp,
                "Predictive Equality": pe,
                "Treatment Equality":  te,
                "ABROCA":              abroca,
            }
        )

    df_results = pd.DataFrame(results)
    avg_results = df_results.mean().round(4)

    print(f"\n===== Average Results Across Folds (DT Model) | {dataset_name} =====")
    print(avg_results.to_frame(name="Average DT (10-Fold)").T)

    avg_results_df = avg_results.reset_index()
    avg_results_df.columns = ["Fairness Metric", "DT"]

    # Optional per-dataset CSV
    # out_name = f"{dataset_name}_dt_results_new1.csv"
    # avg_results_df.to_csv(OUTPUT_DIR / out_name, index=False)
    # print(f"Saved per-dataset DT results: {out_name}")

    return avg_results_df

# %%
def run_all_datasets_dt():
    dataset_names = [
        "Law-Original", "Law-Synthetic", "Law-Debiased", "Law-FLAI", "Law-DECAF",
        "Adult-Original", "Adult-Synthetic", "Adult-Debiased", "Adult-FLAI", "Adult-DECAF",
        "Compas-Original", "Compas-Synthetic", "Compas-Debiased", "Compas-FLAI", "Compas-DECAF",
        "Compas-Violent-Original", "Compas-Violent-Synthetic", "Compas-Violent-Debiased",
        "Compas-Violent-FLAI", "Compas-Violent-DECAF",
        "Diabetes-Original", "Diabetes-Synthetic", "Diabetes-Debiased",
        # "Diabetes-FLAI", 
        "Diabetes-DECAF",
        "Dutch-Original", "Dutch-Synthetic", "Dutch-Debiased",
        "Dutch-FLAI", "Dutch-DECAF",
        # "Compas-FLAI", "Compas-Violent-FLAI"
    ]

    all_results = []

    for name in dataset_names:
        print("\n===========================================")
        print(f"Running DT on dataset: {name}")

        (
            X,
            y,
            sa_index,
            p_Group,
            protected_attribute,
            filename,
            majority_group_name,
            minority_group_name,
        ) = load_dataset(name)

        avg_df = run_experiment_dt(
            X,
            y,
            sa_index,
            p_Group,
            protected_attribute,
            filename,
            majority_group_name,
            minority_group_name,
            dataset_name=name,
        )

        avg_df.insert(0, "Dataset", name)
        all_results.append(avg_df)

    combined = pd.concat(all_results, ignore_index=True)

    # Final combined CSV / Excel
    # combined.to_csv(OUTPUT_DIR / "Combined_DT_results.csv", index=False)
    # Or:
    # combined.to_excel("Combined_DT_results.xlsx", index=False)

    print("\nSaved Combined_DT_results.csv with all datasets.")
    return combined

combined_dt_results = run_all_datasets_dt()
# Out:
# ===========================================
# Running DT on dataset: Law-Original
#
# ===== Average Results Across Folds (DT Model) | Law-Original =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)    0.8468             0.6302              0.0141
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)             0.0106          0.0507              0.013
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)               0.0401             -0.1182  0.0185
#
# ===========================================
# Running DT on dataset: Law-Synthetic
#
# ===== Average Results Across Folds (DT Model) | Law-Synthetic =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)    0.6245             0.6253             -0.0019
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)             0.0246          0.0467             0.0218
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)               0.0221              0.0671  0.0209
#
# ===========================================
# Running DT on dataset: Law-Debiased
#
# ===== Average Results Across Folds (DT Model) | Law-Debiased =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)    0.5389             0.5042              0.0427
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)             0.0499          0.1155             0.0263
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)               0.0656              0.1753  0.0394
#
# ===========================================
# Running DT on dataset: Law-FLAI
#
# ===== Average Results Across Folds (DT Model) | Law-FLAI =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)    0.8551             0.5957              0.0107
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)             0.0185          0.0834             0.0148
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)               0.0649             -0.0058   0.044
#
# ===========================================
# Running DT on dataset: Law-DECAF
#
# ===== Average Results Across Folds (DT Model) | Law-DECAF =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)    0.9905             0.9634              0.2856
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)             0.9321          0.9617             0.9275
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)               0.0295                 inf     NaN
#
# ===========================================
# Running DT on dataset: Adult-Original
#
# ===== Average Results Across Folds (DT Model) | Adult-Original =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)    0.8088              0.748             -0.1982
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)             0.0669          0.1781             0.0867
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)               0.1112              0.0686  0.0389
#
# ===========================================
# Running DT on dataset: Adult-Synthetic
#
# ===== Average Results Across Folds (DT Model) | Adult-Synthetic =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)    0.6825             0.6822              0.0102
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)             0.0323          0.0632             0.0393
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)               0.0309                0.04  0.0272
#
# ===========================================
# Running DT on dataset: Adult-Debiased
#
# ===== Average Results Across Folds (DT Model) | Adult-Debiased =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)    0.6353             0.6106             -0.0017
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)              0.039          0.0951             0.0373
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)               0.0562             -0.0447  0.0437
#
# ===========================================
# Running DT on dataset: Adult-FLAI
#
# ===== Average Results Across Folds (DT Model) | Adult-FLAI =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)    0.7717             0.6731              0.1468
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)              0.105          0.1886             0.1527
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)               0.0836             -0.1879  0.0777
#
# ===========================================
# Running DT on dataset: Adult-DECAF
#
# ===== Average Results Across Folds (DT Model) | Adult-DECAF =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)    0.9977             0.9976               0.977
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)             0.1205           0.208             0.0721
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)               0.0876                 NaN   0.074
#
# ===========================================
# Running DT on dataset: Compas-Original
#
# ===== Average Results Across Folds (DT Model) | Compas-Original =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)    0.6397             0.6259             -0.1583
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)             0.1591           0.271             0.1522
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)                0.112             -2.4843  0.0791
#
# ===========================================
# Running DT on dataset: Compas-Synthetic
#
# ===== Average Results Across Folds (DT Model) | Compas-Synthetic =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)    0.7118             0.4953              0.0274
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)             0.0355          0.0603              0.033
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)               0.0248              0.0891  0.0359
#
# ===========================================
# Running DT on dataset: Compas-Debiased
#
# ===== Average Results Across Folds (DT Model) | Compas-Debiased =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)    0.5065             0.5066             -0.0269
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)             0.0414          0.0954             0.0324
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)                0.054             -0.0902  0.0359
#
# ===========================================
# Running DT on dataset: Compas-FLAI
#
# ===== Average Results Across Folds (DT Model) | Compas-FLAI =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)    0.6926             0.6767              0.0828
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)              0.107          0.1436             0.0791
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)               0.0366              0.3229  0.0477
#
# ===========================================
# Running DT on dataset: Compas-DECAF
#
# ===== Average Results Across Folds (DT Model) | Compas-DECAF =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)    0.9886             0.9812              0.7633
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)             0.1457           0.184             0.0466
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)               0.0384                 inf  0.0232
#
# ===========================================
# Running DT on dataset: Compas-Violent-Original
#
# ===== Average Results Across Folds (DT Model) | Compas-Violent-Original =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)    0.8112             0.5737             -0.0589
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)             0.1477          0.1862             0.2728
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)               0.0385             -0.9542  0.1773
#
# ===========================================
# Running DT on dataset: Compas-Violent-Synthetic
#
# ===== Average Results Across Folds (DT Model) | Compas-Violent-Synthetic =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)    0.6235             0.5063              0.0543
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)             0.0487          0.1154             0.0715
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)               0.0667              1.4327  0.0638
#
# ===========================================
# Running DT on dataset: Compas-Violent-Debiased
#
# ===== Average Results Across Folds (DT Model) | Compas-Violent-Debiased =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)    0.8008             0.5535             -0.0189
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)             0.0622          0.0796             0.0636
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)               0.0174             -1.0855  0.0501
#
# ===========================================
# Running DT on dataset: Compas-Violent-FLAI
#
# ===== Average Results Across Folds (DT Model) | Compas-Violent-FLAI =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)    0.8357             0.5703             -0.0018
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)             0.1225          0.1352             0.1432
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)               0.0127             -1.2423  0.0751
#
# ===========================================
# Running DT on dataset: Compas-Violent-DECAF
#
# ===== Average Results Across Folds (DT Model) | Compas-Violent-DECAF =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)    0.8154             0.7336             -0.5166
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)             0.6748          0.8807             0.2225
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)               0.2059            -21.0119  0.1973
#
# ===========================================
# Running DT on dataset: Diabetes-Original
#
# ===== Average Results Across Folds (DT Model) | Diabetes-Original =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)    0.6452             0.5285              -0.002
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)             0.0079          0.0298              0.011
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)               0.0218             -0.0455  0.0116
#
# ===========================================
# Running DT on dataset: Diabetes-Synthetic
#
# ===== Average Results Across Folds (DT Model) | Diabetes-Synthetic =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)    0.6266             0.6194             -0.0088
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)              0.023          0.0506             0.0246
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)               0.0277              0.0494  0.0194
#
# ===========================================
# Running DT on dataset: Diabetes-Debiased
#
# ===== Average Results Across Folds (DT Model) | Diabetes-Debiased =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)    0.6719             0.6696              0.0087
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)             0.0315          0.0687             0.0291
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)               0.0372              0.0123  0.0243
#
# ===========================================
# Running DT on dataset: Diabetes-DECAF
#
# ===== Average Results Across Folds (DT Model) | Diabetes-DECAF =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)    0.6012             0.5008               0.001
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)             0.0205           0.071             0.0295
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)               0.0504              -0.027  0.0257
#
# ===========================================
# Running DT on dataset: Dutch-Original
#
# ===== Average Results Across Folds (DT Model) | Dutch-Original =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)     0.817             0.8157             -0.3319
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)             0.0925           0.308             0.0131
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)               0.2155             -0.6223  0.0543
#
# ===========================================
# Running DT on dataset: Dutch-Synthetic
#
# ===== Average Results Across Folds (DT Model) | Dutch-Synthetic =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)    0.6424             0.6265             -0.0168
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)             0.0401          0.0726             0.0337
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)               0.0325             -0.0354  0.0287
#
# ===========================================
# Running DT on dataset: Dutch-Debiased
#
# ===== Average Results Across Folds (DT Model) | Dutch-Debiased =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)    0.5139             0.5099             -0.0262
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)              0.036          0.0687             0.0306
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)               0.0327             -0.0045  0.0207
#
# ===========================================
# Running DT on dataset: Dutch-FLAI
#
# ===== Average Results Across Folds (DT Model) | Dutch-FLAI =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)    0.7899             0.7883              0.2274
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)              0.065          0.2531             0.0337
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)               0.1881              0.1409   0.062
#
# ===========================================
# Running DT on dataset: Dutch-DECAF
#
# ===== Average Results Across Folds (DT Model) | Dutch-DECAF =====
#                       Accuracy  Balanced Accuracy  Statistical Parity  \
# Average DT (10-Fold)     0.532             0.5121              0.1815
#
#                       Equal Opportunity  Equalized Odds  Predictive Parity  \
# Average DT (10-Fold)             0.1944          1.0242             0.5047
#
#                       Predictive Equality  Treatment Equality  ABROCA
# Average DT (10-Fold)               0.1702                 inf     NaN
#
# Saved Combined_DT_results.csv with all datasets.
